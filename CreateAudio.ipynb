# %%
# !pip install gtts
# Out:
# Collecting gtts
#   Downloading gTTS-2.5.2-py3-none-any.whl (29 kB)
# Requirement already satisfied: requests<3,>=2.27 in /usr/local/lib/python3.10/dist-packages (from gtts) (2.31.0)
# Requirement already satisfied: click<8.2,>=7.1 in /usr/local/lib/python3.10/dist-packages (from gtts) (8.1.7)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.27->gtts) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.27->gtts) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.27->gtts) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.27->gtts) (2024.7.4)
# Installing collected packages: gtts
# Successfully installed gtts-2.5.2

# %%
from gtts import gTTS

def generate_audio(text, filename="output.mp3"):
    tts = gTTS(text=text, lang='en')
    tts.save(filename)

def get_download_link(filename="output.mp3"):
    return f"/content/drive/MyDrive/AvatarAudio/{filename}"

# %%
questions = [
    "Welcome to The Hull-Ellis Concussion and Research Clinic! My name is Act-A. I'll ask you some questions related to you and your injury. Let's get started. What's your full name?",
    "How old are you?",
    "What's your sex?",
    "What was the date of your injury?",
    "How did your injury occur?",
    "What is the last thing you remember from before your injury?",
    "What is the first thing you remember from after your injury?",
    "Did you lose consciousness?",
    "How long were you unconscious for?",
    "Was your injury witnessed by anyone else?",
    "Did you feel dazed or confused at the time of your injury?",
    "How long did that feeling last?",
    "Was your injury witnessed by anyone else?",
    "When your concussion occurred, did you have any other injuries to your body, not related to the head or neck area, for example, your knees or back?",
    "Before this injury, had you ever been diagnosed with a concussion by a medical professional?",
    "How many times?",
    "When was the most recent diagnosed concussion before this new injury?",
    "How long did it take you to recover, or get back to normal, after your previous concussions?",
    "Before this injury, had you ever injured your head or neck, but were not diagnosed with a concussion?",
    "How many times?",
    "When was the most recent incident before this new injury?",
    "How long did it take you to recover, or get back to normal, after those injuries?"
]

for i, question in enumerate(questions):
    filename = f"question{i+1}.mp3"
    generate_audio(question, filename)
    download_link = get_download_link(filename)
    print(f"Direct download link for {filename}: {download_link}")
# Out:
# Direct download link for question1.mp3: /content/drive/MyDrive/AvatarAudio/question1.mp3
# Direct download link for question2.mp3: /content/drive/MyDrive/AvatarAudio/question2.mp3
# Direct download link for question3.mp3: /content/drive/MyDrive/AvatarAudio/question3.mp3
# Direct download link for question4.mp3: /content/drive/MyDrive/AvatarAudio/question4.mp3
# Direct download link for question5.mp3: /content/drive/MyDrive/AvatarAudio/question5.mp3
# Direct download link for question6.mp3: /content/drive/MyDrive/AvatarAudio/question6.mp3
# Direct download link for question7.mp3: /content/drive/MyDrive/AvatarAudio/question7.mp3
# Direct download link for question8.mp3: /content/drive/MyDrive/AvatarAudio/question8.mp3
# Direct download link for question9.mp3: /content/drive/MyDrive/AvatarAudio/question9.mp3
# Direct download link for question10.mp3: /content/drive/MyDrive/AvatarAudio/question10.mp3
# Direct download link for question11.mp3: /content/drive/MyDrive/AvatarAudio/question11.mp3
# Direct download link for question12.mp3: /content/drive/MyDrive/AvatarAudio/question12.mp3
# Direct download link for question13.mp3: /content/drive/MyDrive/AvatarAudio/question13.mp3
# Direct download link for question14.mp3: /content/drive/MyDrive/AvatarAudio/question14.mp3
# Direct download link for question15.mp3: /content/drive/MyDrive/AvatarAudio/question15.mp3
# Direct download link for question16.mp3: /content/drive/MyDrive/AvatarAudio/question16.mp3
# Direct download link for question17.mp3: /content/drive/MyDrive/AvatarAudio/question17.mp3
# Direct download link for question18.mp3: /content/drive/MyDrive/AvatarAudio/question18.mp3
# Direct download link for question19.mp3: /content/drive/MyDrive/AvatarAudio/question19.mp3
# Direct download link for question20.mp3: /content/drive/MyDrive/AvatarAudio/question20.mp3
# Direct download link for question21.mp3: /content/drive/MyDrive/AvatarAudio/question21.mp3
# Direct download link for question22.mp3: /content/drive/MyDrive/AvatarAudio/question22.mp3
